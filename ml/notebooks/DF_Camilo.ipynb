# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/processed/df_Nuevo.parquet')

# %%
df.sample(10)
# Out:
#                 CVE_ID  IS_KEV  RISK_TIER  RISK_SCORE  EPSS_SCORE  \
# 79553    CVE-2016-0793       0          4    0.599933     0.35266
# 77149    CVE-2015-7888       0          4    0.489712     0.03773
# 235859  CVE-2024-24766       0          2    0.337190     0.00467
# 166315  CVE-2021-22961       0          3    0.387858     0.00956
# 43842    CVE-2010-3236       0          4    0.515435     0.56267
# 104548   CVE-2018-8073       0          3    0.387203     0.00911
# 195762   CVE-2022-4643       0          4    0.450589     0.03837
# 76152    CVE-2015-8722       0          0    0.155768     0.00076
# 22272    CVE-2006-7134       0          3    0.363510     0.03860
# 168634   CVE-2021-4075       0          4    0.443545     0.00274
#
#         EPSS_PERCENTILE  SCORE_BASE  SEVERITY VEC_ATAQUE COMPLEJIDAD  ...  \
# 79553           0.97077         7.5      HIGH    NETWORK         LOW  ...
# 77149           0.88125         7.5      HIGH    NETWORK         LOW  ...
# ...

# %%
df.shape
# Out:
# (325485, 26)

# %%
df.columns
# Out:
# Index(['CVE_ID', 'IS_KEV', 'RISK_TIER', 'RISK_SCORE', 'EPSS_SCORE',
#        'EPSS_PERCENTILE', 'SCORE_BASE', 'SEVERITY', 'VEC_ATAQUE',
#        'COMPLEJIDAD', 'PRIVILEGIOS', 'INTERACCION', 'DAYS_SINCE_PUBLISHED',
#        'VENDOR', 'PRODUCT', 'CWE', 'VENDOR_TOKENS', 'PRODUCT_TOKENS',
#        'CWE_TOKENS', 'VENDOR_GROUPS_STR', 'PRODUCT_GROUPS_STR',
#        'CWE_TECH_GROUPS_STR', 'CWE_CANONICAL_STR', 'N_VENDOR_GROUPS',
#        'N_PRODUCT_GROUPS', 'N_CWE_GROUPS'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 325485 entries, 0 to 325484
# Data columns (total 26 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   CVE_ID                325485 non-null  str
#  1   IS_KEV                325485 non-null  int32
#  2   RISK_TIER             325485 non-null  int64
#  3   RISK_SCORE            325485 non-null  float64
#  4   EPSS_SCORE            325485 non-null  float64
#  5   EPSS_PERCENTILE       325485 non-null  float64
#  6   SCORE_BASE            325485 non-null  float64
#  7   SEVERITY              325485 non-null  str
#  8   VEC_ATAQUE            325485 non-null  str
#  9   COMPLEJIDAD           325485 non-null  str
#  10  PRIVILEGIOS           325485 non-null  str
#  11  INTERACCION           325485 non-null  str
#  12  DAYS_SINCE_PUBLISHED  325485 non-null  int64
#  13  VENDOR                325485 non-null  str
#  14  PRODUCT               325485 non-null  str
# ...
